# %% [markdown]
# #1.grocery billing

# %%
p1=int(input('price of the item 1'))
q1=int(input('quantity of the item 1'))
p2=int(input('price of the item 2'))
q2=int(input('quantity of the item 2'))
total=p1*q1+p2*q2
print(total)
# Out:
# price of the item 1100
# quantity of the item 13
# price of the item 2200
# quantity of the item 22
# 700

# %% [markdown]
# #2.temperature conversion

# %%
c= float(input("Enter temperature in Celsius: "))
f= (c * 9/5) + 32
print("temperature in farenheit is",f)
# Out:
# Enter temperature in Celsius: 30
# temperature in farenheit is 86.0

# %% [markdown]
# #3.salary slip

# %%
basic_salary = float(input("Enter the basic salary: "))
hra = 0.20 * basic_salary
da = 0.10 * basic_salary

total_salary = basic_salary + hra + da

print("Basic Salary: ",basic_salary)
print("HRA (20%): ",hra)
print("DA (10%): ",da)
print("Total Salary: ",total_salary)
# Out:
# Enter the basic salary: 20000
# Basic Salary:  20000.0
# HRA (20%):  4000.0
# DA (10%):  2000.0
# Total Salary:  26000.0

# %% [markdown]
# #4.simple interest

# %%
p=float(input("enter the principle amount"))
r=float(input("enter the rate of interest"))
t=float(input("enter the time period"))
si=(p*r*t)/100
print("simple interest is",si)
# Out:
# enter the principle amount10000
# enter the rate of interest5
# enter the time period2
# simple interest is 1000.0

# %% [markdown]
# #5.time conversion

# %%
m=float(input("Enter minutes: "))
h=m//60
rm=m%60
print(h,"hours",rm,"remaining minutes")
# Out:
# Enter minutes: 130
# 2.0 hours 10.0 remaining minutes

# %% [markdown]
# #6.Bmi calculator

# %%
w=float(input("enter the weight in kg"))
h=float(input("enter the height in m"))
bmi=w/(h*h)
print("bmi is",bmi)
# Out:
# enter the weight in kg60
# enter the height in m1.65
# bmi is 22.03856749311295

# %% [markdown]
# #7.discount calculation

# %%
op=float(input("enter the original price"))
discount=0.10*op
new_price = op-discount
print("new price is",new_price)
# Out:
# enter the original price1200
# new price is 1080.0

# %% [markdown]
# #8.area of triangle(using herons formula)

# %%
a = float(input("Enter the length of side a: "))
b = float(input("Enter the length of side b: "))
c = float(input("Enter the length of side c: "))
s = (a + b + c) / 2
area=(s*(s-a)*(s-b)*(s-c))**0.5
print("The area of the triangle is: ",area)
# Out:
# Enter the length of side a: 5
# Enter the length of side b: 6
# Enter the length of side c: 7
# The area of the triangle is:  14.696938456699069

# %% [markdown]
# #9.paint cost estimator

# %%
l=float(input("enter the length of the wall"))
b=float(input("enter the breadth of the wall"))
area=(l-2*1.5)*(h-2*1.2)
cost=area*25
print(area)
print(cost)
# Out:
# enter the length of the wall12
# enter the breadth of the wall8
# -6.75
# -168.75

# %% [markdown]
# #10.electricity bill calculator

# %%
C=float(input('Enter the number of units consumed'))
fixed_charge=100
rate_per_unit=5.2
total_bill=C*rate_per_unit+fixed_charge
print(total_bill)
# Out:
# Enter the number of units consumed250
# 1400.0
