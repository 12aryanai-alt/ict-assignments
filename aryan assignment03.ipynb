# %% [markdown]
# #1.write a python function to find the max of three numbers

# %%
def max_of_three(a,b,c):
  if a>b and a>c:
    return a
  elif b>a and b>c:
    return b
  else:
    return c

a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
print(max_of_three(a,b,c))
# Out:
# enter the first number:1
# enter the second number:2
# enter the third number:3
# 3

# %% [markdown]
# #2.write a python function to sum all the numbers in a list

# %%
def sum_of_numbers(list):
  total = 0
  for i in list:
    total += i
  return total

int_list = [1, 2, 3, 4, 5]
print(sum_of_numbers(int_list))
# Out:
# 15

# %% [markdown]
# #3.Python program to insert a number to any position in a list (Get the numberto be inserted and position from the user)

# %%
list=[10,20,30,40,50]

num=int(input("enter the number:"))
pos=int(input("enter the position:"))
list.insert(pos,num)
print(list)
# Out:
# enter the number:13
# enter the position:5
# [10, 20, 30, 40, 50, 13]

# %% [markdown]
# #4.write a program to rename a key city to a locatiopn in the following dictionary

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
sample_dict['location'] = sample_dict.pop('city')
print(sample_dict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# #5.write a program to insert a number to any position in a list (get the number to be inserted and position from the user

# %%
dict = { 'emp1': {'name': 'Jhon', 'salary': 7500},
'emp2': {'name': 'Emma', 'salary': 8000},
'emp3': {'name': 'Brad', 'salary': 500}, }
dict['emp3']['salary'] = 8500
print(dict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# #6.write a program to copy elements 44 and 55 from the following tuple into a new tuple .given tuple1=(11,22,33,44,55,66)

# %%
tuple1 = (11, 22, 33, 44, 55, 66)
tuple2 = tuple1[3:5]
print(tuple2)
# Out:
# (44, 55)

# %% [markdown]
# #7.counts the number of occurences of item 50 from a tuple tuple1=(50,10,60,70,50,83,567,50,81)

# %%
tuple1 = (50, 10, 60, 70, 50, 83,567,50,81)
count = tuple1.count(50)
print("number of occurences of item 50 :",count)
# Out:
# number of occurences of item 50 : 3
